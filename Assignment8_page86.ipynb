# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
names = ['Bob','Jessica','Mary','John','Mel']
absences = [3,0,1,0,8]
detentions = [2,1,0,0,1]
warnings = [2,1,5,1,2]

# %%
GradeList = list(zip(names,absences,detentions,warnings))
columns=['Names', 'Absences', 'Detentions','Warnings']
df = pd.DataFrame(data = GradeList, columns=columns)

# %%
df['TotalDemerits'] = df['Absences'] +df['Detentions'] + df['Warnings']

# %%
plt.pie(df['TotalDemerits'])
# Out:
# ([<matplotlib.patches.Wedge at 0x2471b96f6d8>,
#   <matplotlib.patches.Wedge at 0x2471b96fbe0>,
#   <matplotlib.patches.Wedge at 0x2471b9840f0>,
#   <matplotlib.patches.Wedge at 0x2471b9845c0>,
#   <matplotlib.patches.Wedge at 0x2471b984a90>],
#  [Text(0.7548658155281622, 0.8001109926422726, ''),
#   Text(-0.3154835212675114, 1.0537884739399326, ''),
#   Text(-1.0336618730799265, 0.3762221845411275, ''),
#   Text(-0.9829959141992366, -0.49367907862052174, ''),
#   Text(0.3154835212675113, -1.0537884739399326, '')])

# %%
#customised
plt.pie(df['TotalDemerits'],
       labels= df['Names'],
       explode=(0,0,0,0,0.05),
       startangle=90,
       autopct='%1.1f%%',)
plt.axis('equal')
plt.show()

# %%
#Task
plt.pie(df['TotalDemerits'],
       labels= df['Names'],
       explode=(0,0,0,0.3,0),
       startangle=220,
       autopct='%1.1f%%',)
plt.axis('equal')
plt.show()
