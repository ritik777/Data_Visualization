# %%
import pandas as pd
Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)
df.head()
# Out:
#      fname     lname  gender  age  exercise  hours  grade  \
# 0   Marcia      Pugh  female   17         3     10   82.4
# 1   Kadeem  Morrison    male   18         4      4   78.2
# 2     Nash    Powell    male   18         5      9   79.3
# 3  Noelani    Wagner  female   14         2      7   83.2
# 4  Noelani    Cherry  female   18         4     15   87.4
#
#                                     address
# 0   9253 Richardson Road, Matawan, NJ 07747
# 1          33 Spring Dr., Taunton, MA 02780
# 2          41 Hill Avenue, Mentor, OH 44060
# 3        8839 Marshall St., Miami, FL 33125
# 4  8304 Charles Rd., Lewis Center, OH 43035

# %%
df.sort_values(by=["fname","age","grade"],ascending=[True,True,True])
# Out:
#          fname      lname  gender  age  exercise  hours  grade  \
# 435      Aaron    Knowles    male   16         4     11   88.7
# 721      Aaron      Salas    male   19         4     10   86.7
# 340      Abbot       Hall    male   16         4      3   58.9
# 1690     Abbot     Kramer    male   16         2      8   81.0
# 1901     Abbot     Kinney    male   16         4     18   87.5
# 817      Abbot  Daugherty    male   17         1      9   82.3
# 836       Abel   Stephens    male   18         4      2   68.2
# 771    Abigail  Rodriguez  female   14         5      8   81.5
# 1597      Abra      Tyler  female   15         2      9   71.7
# 1159      Abra       Neal  female   16         1     14   80.1
# 1326   Abraham     Snider    male   16         1      4   73.3
# 643    Abraham  Mccormick    male   18         2     10   73.7
# 1133   Abraham       Kent    male   19         2      5   62.6
# 1436     Acton     Bright    male   14         2      8   67.0
# ...
