# %%
import pandas as pd
import numpy as np
Location = "datasets/gradedata.csv"
df = pd.read_csv(Location)

# %%
df.take(np.random.permutation(len(df))[:100])
# Out:
#           fname      lname  gender  age  exercise  hours  grade  \
# 326       Reese    Morales    male   19         2      8   71.2
# 1572      Bryar     Watson  female   14         1     11   80.8
# 1060      Linda     Arnold  female   16         5      8   82.0
# 176       Quail     Bonner  female   18         5      6   68.0
# 1883      Jayme   Ferguson  female   19         2     12   90.7
# 1097  Alexandra      Bowen  female   18         4     15   98.2
# 952        Lane      Keith    male   16         1      8   79.9
# 1302      Devin   Roberson    male   14         4     15   99.7
# 1069     Samuel     Spence    male   17         2     13   86.5
# 222     Destiny     Hansen  female   18         1     17   91.9
# 540      Clarke      Mills    male   17         2      9   83.1
# 382       Jacob       Gray    male   15         3     17  100.0
# 1647       Gray   Harrison    male   17         2      9   71.2
# 963      Hayley    Aguirre  female   19         4     14   85.8
# ...
